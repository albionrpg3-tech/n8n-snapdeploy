# %%
# !pip install iopaint

# %%
# !iopaint run --model=lama --image=/content/drive/MyDrive/Fotos_Originales/ --mask=/content/drive/MyDrive/Mascaras/ --output=/content/drive/MyDrive/Fotos_Limpias/
# Out:
# 2026-08-13 14:49:22.256 | INFO     | iopaint.runtime:setup_model_dir:81 - Model directory: /root/.cache
# /usr/local/lib/python3.12/dist-packages/iopaint/model/ldm.py:279: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   @torch.cuda.amp.autocast()
# ╭───────────────────── Traceback (most recent call last) ──────────────────────╮
# │ /usr/local/lib/python3.12/dist-packages/iopaint/cli.py:94 in run             │
# │                                                                              │
# │    91 │                                                                      │
# │    92 │   from iopaint.batch_processing import batch_inpaint                 │
# │    93 │                                                                      │
# │ ❱  94 │   batch_inpaint(model, device, image, mask, output, config, concat)  │
# │    95                                                                        │
# ...
